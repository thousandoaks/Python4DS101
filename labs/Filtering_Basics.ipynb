# %% [markdown]
# <a href="https://colab.research.google.com/github/thousandoaks/Python4DS101/blob/master/labs/Filtering_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Filtering Basics

# %% [markdown]
# ## What I hope you'll get out of this lab
# * The ability to use basic filtering operations to process DataFrames
# * The ability to develop advanced filters based on the composition of basic ones
# * Resources to look further

# %% [markdown]
# ##  Comparison operators
# ### Comparison operators allow us to ask if something is true or false.

# %%
FirstVariable=50

# %%
SecondVariable=150

# %%
ThirdVariable=50

# %% [markdown]
# #### Question 1. is FirstVariable equal to SecondVariable ?

# %%
FirstVariable==SecondVariable
# Out:
# False

# %% [markdown]
# #### Question 2. is FirstVariable equal to ThirdVariable ?

# %%
FirstVariable==ThirdVariable
# Out:
# True

# %% [markdown]
# #### Question 3. is FirstVariable larger than SecondVariable ?

# %%
FirstVariable>SecondVariable
# Out:
# False

# %% [markdown]
# #### Question 4. is SecondVariable equal or larger than ThirdVariable ?

# %%
SecondVariable>=ThirdVariable
# Out:
# True

# %% [markdown]
# ### The following image lists the comparison operators supported by Python:
#
# <img src="https://github.com/thousandoaks/Python4DS101/blob/master/images/comparisonoperators.png?raw=1" width="50%"/>

# %% [markdown]
# ## Filter-based selection in Pandas
# ### Filters rely on comparison operators to determine if a condition is true or false.

# %% [markdown]
# ### Let's load our gapminder DataSet to start with

# %%
# we import the library pandas and give it the "pd" kickname
import pandas as pd

# %%
# we use pandas.read_csv() function to access the file "gapminder.tsv" stored in a remote location 

# the remote location is: https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/

# with the argument sep='\t' we indicate that the columns are separated by tabs rather than commas.

gapminderDataFrame = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
gapminderDataFrame.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %% [markdown]
# ### Example 1. Given our Gapminder DataSet let's select countries in Asia

# %% [markdown]
# ### Step A. We define the filtering condition
# #### in this case, we want to select countries in the asian continent

# %%
gapminderDataFrame['continent']=='Asia'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: continent, Length: 1704, dtype: bool

# %% [markdown]
# ### Step B. We save the filtering condition

# %%
asiaFilter=gapminderDataFrame['continent']=='Asia'

# %% [markdown]
# ### Step C. We apply the filtering condition
# #### if the filter works as intended you will get only observations fullfilling the condition continent=='Asia'

# %%
gapminderDataFrame[asiaFilter]
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# ...           ...       ...   ...      ...       ...          ...
# 1675  Yemen, Rep.      Asia  1987   52.922  11219340  1971.741538
# 1676  Yemen, Rep.      Asia  1992   55.599  13367997  1879.496673
# 1677  Yemen, Rep.      Asia  1997   58.020  15826497  2117.484526
# 1678  Yemen, Rep.      Asia  2002   60.308  18701257  2234.820827
# 1679  Yemen, Rep.      Asia  2007   62.698  22211743  2280.769906
#
# [396 rows x 6 columns]

# %% [markdown]
# ### Example 2. Given our Gapminder DataSet let's select countries with a population larger than 100.000.000 people

# %% [markdown]
# ### Step A. We define the filtering condition
# #### in this case, we want to select countries whose population is larger than 100.000.000 people

# %%
gapminderDataFrame['pop']>=100000000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: pop, Length: 1704, dtype: bool

# %% [markdown]
# ### Step B. We save the filtering condition

# %%
largePopulationFilter=gapminderDataFrame['pop']>=1000000000

# %% [markdown]
# #### Step C. We apply the filtering condition
# #### if the filter works as intended you will get only observations fullfilling the condition population larger than 100 million

# %%
gapminderDataFrame[largePopulationFilter]
# Out:
#     country continent  year  lifeExp         pop    gdpPercap
# 294   China      Asia  1982   65.525  1000281000   962.421381
# 295   China      Asia  1987   67.274  1084035000  1378.904018
# 296   China      Asia  1992   68.690  1164970000  1655.784158
# 297   China      Asia  1997   70.426  1230075000  2289.234136
# 298   China      Asia  2002   72.028  1280400000  3119.280896
# 299   China      Asia  2007   72.961  1318683096  4959.114854
# 706   India      Asia  2002   62.879  1034172547  1746.769454
# 707   India      Asia  2007   64.698  1110396331  2452.210407

# %% [markdown]
# ### Example 3. Given our Gapminder DataSet let's select observations from Germany

# %% [markdown]
# #### Step A. We define the filtering condition
# #### in this case, we want to select observations corresponding to Germany
# #### But.. how do we look for Germany ??

# %%
pd.set_option('display.max_rows', 200)
gapminderDataFrame.groupby('country').count()
# Out:
#                           continent  year  lifeExp  pop  gdpPercap
# country
# Afghanistan                      12    12       12   12         12
# Albania                          12    12       12   12         12
# Algeria                          12    12       12   12         12
# Angola                           12    12       12   12         12
# Argentina                        12    12       12   12         12
# Australia                        12    12       12   12         12
# Austria                          12    12       12   12         12
# Bahrain                          12    12       12   12         12
# Bangladesh                       12    12       12   12         12
# Belgium                          12    12       12   12         12
# Benin                            12    12       12   12         12
# Bolivia                          12    12       12   12         12
# Bosnia and Herzegovina           12    12       12   12         12
# Botswana                         12    12       12   12         12
# Brazil                           12    12       12   12         12
# Bulgaria                         12    12       12   12         12
# Burkina Faso                     12    12       12   12         12
# Burundi                          12    12       12   12         12
# Cambodia                         12    12       12   12         12
# Cameroon                         12    12       12   12         12
# Canada                           12    12       12   12         12
# Central African Republic         12    12       12   12         12
# Chad                             12    12       12   12         12
# Chile                            12    12       12   12         12
# China                            12    12       12   12         12
# Colombia                         12    12       12   12         12
# Comoros                          12    12       12   12         12
# Congo, Dem. Rep.                 12    12       12   12         12
# Congo, Rep.                      12    12       12   12         12
# Costa Rica                       12    12       12   12         12
# Cote d'Ivoire                    12    12       12   12         12
# Croatia                          12    12       12   12         12
# Cuba                             12    12       12   12         12
# Czech Republic                   12    12       12   12         12
# Denmark                          12    12       12   12         12
# Djibouti                         12    12       12   12         12
# Dominican Republic               12    12       12   12         12
# Ecuador                          12    12       12   12         12
# Egypt                            12    12       12   12         12
# El Salvador                      12    12       12   12         12
# Equatorial Guinea                12    12       12   12         12
# Eritrea                          12    12       12   12         12
# Ethiopia                         12    12       12   12         12
# Finland                          12    12       12   12         12
# France                           12    12       12   12         12
# Gabon                            12    12       12   12         12
# Gambia                           12    12       12   12         12
# Germany                          12    12       12   12         12
# Ghana                            12    12       12   12         12
# Greece                           12    12       12   12         12
# Guatemala                        12    12       12   12         12
# Guinea                           12    12       12   12         12
# Guinea-Bissau                    12    12       12   12         12
# Haiti                            12    12       12   12         12
# Honduras                         12    12       12   12         12
# Hong Kong, China                 12    12       12   12         12
# Hungary                          12    12       12   12         12
# Iceland                          12    12       12   12         12
# India                            12    12       12   12         12
# Indonesia                        12    12       12   12         12
# Iran                             12    12       12   12         12
# Iraq                             12    12       12   12         12
# Ireland                          12    12       12   12         12
# Israel                           12    12       12   12         12
# Italy                            12    12       12   12         12
# Jamaica                          12    12       12   12         12
# Japan                            12    12       12   12         12
# Jordan                           12    12       12   12         12
# Kenya                            12    12       12   12         12
# Korea, Dem. Rep.                 12    12       12   12         12
# Korea, Rep.                      12    12       12   12         12
# Kuwait                           12    12       12   12         12
# Lebanon                          12    12       12   12         12
# Lesotho                          12    12       12   12         12
# Liberia                          12    12       12   12         12
# Libya                            12    12       12   12         12
# Madagascar                       12    12       12   12         12
# Malawi                           12    12       12   12         12
# Malaysia                         12    12       12   12         12
# Mali                             12    12       12   12         12
# Mauritania                       12    12       12   12         12
# Mauritius                        12    12       12   12         12
# Mexico                           12    12       12   12         12
# Mongolia                         12    12       12   12         12
# Montenegro                       12    12       12   12         12
# Morocco                          12    12       12   12         12
# Mozambique                       12    12       12   12         12
# Myanmar                          12    12       12   12         12
# Namibia                          12    12       12   12         12
# Nepal                            12    12       12   12         12
# Netherlands                      12    12       12   12         12
# New Zealand                      12    12       12   12         12
# Nicaragua                        12    12       12   12         12
# Niger                            12    12       12   12         12
# Nigeria                          12    12       12   12         12
# Norway                           12    12       12   12         12
# Oman                             12    12       12   12         12
# Pakistan                         12    12       12   12         12
# Panama                           12    12       12   12         12
# Paraguay                         12    12       12   12         12
# Peru                             12    12       12   12         12
# Philippines                      12    12       12   12         12
# Poland                           12    12       12   12         12
# Portugal                         12    12       12   12         12
# Puerto Rico                      12    12       12   12         12
# Reunion                          12    12       12   12         12
# Romania                          12    12       12   12         12
# Rwanda                           12    12       12   12         12
# Sao Tome and Principe            12    12       12   12         12
# Saudi Arabia                     12    12       12   12         12
# Senegal                          12    12       12   12         12
# Serbia                           12    12       12   12         12
# Sierra Leone                     12    12       12   12         12
# Singapore                        12    12       12   12         12
# Slovak Republic                  12    12       12   12         12
# Slovenia                         12    12       12   12         12
# Somalia                          12    12       12   12         12
# South Africa                     12    12       12   12         12
# Spain                            12    12       12   12         12
# Sri Lanka                        12    12       12   12         12
# Sudan                            12    12       12   12         12
# Swaziland                        12    12       12   12         12
# Sweden                           12    12       12   12         12
# Switzerland                      12    12       12   12         12
# Syria                            12    12       12   12         12
# Taiwan                           12    12       12   12         12
# Tanzania                         12    12       12   12         12
# Thailand                         12    12       12   12         12
# Togo                             12    12       12   12         12
# Trinidad and Tobago              12    12       12   12         12
# Tunisia                          12    12       12   12         12
# Turkey                           12    12       12   12         12
# Uganda                           12    12       12   12         12
# United Kingdom                   12    12       12   12         12
# United States                    12    12       12   12         12
# Uruguay                          12    12       12   12         12
# Venezuela                        12    12       12   12         12
# Vietnam                          12    12       12   12         12
# West Bank and Gaza               12    12       12   12         12
# Yemen, Rep.                      12    12       12   12         12
# Zambia                           12    12       12   12         12
# Zimbabwe                         12    12       12   12         12

# %% [markdown]
# #### Now that we know that it is called "Germany" we define the filtering condition accordingly

# %%
gapminderDataFrame['country']=='Germany'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %% [markdown]
# #### Step B. We save the filtering condition

# %%
germanyFilter=gapminderDataFrame['country']=='Germany'

# %% [markdown]
# #### Step C. We apply the filtering condition
# #### if the filter works as intended you will get only observations from Germany

# %%
gapminderDataFrame[germanyFilter]
# Out:
#      country continent  year  lifeExp       pop     gdpPercap
# 564  Germany    Europe  1952   67.500  69145952   7144.114393
# 565  Germany    Europe  1957   69.100  71019069  10187.826650
# 566  Germany    Europe  1962   70.300  73739117  12902.462910
# 567  Germany    Europe  1967   70.800  76368453  14745.625610
# 568  Germany    Europe  1972   71.000  78717088  18016.180270
# 569  Germany    Europe  1977   72.500  78160773  20512.921230
# 570  Germany    Europe  1982   73.800  78335266  22031.532740
# 571  Germany    Europe  1987   74.847  77718298  24639.185660
# 572  Germany    Europe  1992   76.070  80597764  26505.303170
# 573  Germany    Europe  1997   77.340  82011073  27788.884160
# 574  Germany    Europe  2002   78.670  82350671  30035.801980
# 575  Germany    Europe  2007   79.406  82400996  32170.374420

# %% [markdown]
# ## Composite Filtering

# %% [markdown]
# ### Example 3. Given our Gapminder DataSet let's select observations from Germany after 1982

# %% [markdown]
# #### In this example we need a composite filter

# %% [markdown]
# #### Step A. We define the filtering conditions
# #### in this case, we want to select observations corresponding to Germany which also took place from 1982 onwards

# %%
gapminderDataFrame['country']=='Germany'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
gapminderDataFrame['year']>=1982
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699     True
# 1700     True
# 1701     True
# 1702     True
# 1703     True
# Name: year, Length: 1704, dtype: bool

# %% [markdown]
# ### Step B. We save the filtering condition

# %%
germanyFilter=gapminderDataFrame['country']=='Germany'

# %%
Filter1982Onwards=gapminderDataFrame['year']>=1982

# %% [markdown]
# #### Step C. We apply the filtering condition
# #### if the filter works as intended you will get only observations from Germany from 1982 onwards

# %%
gapminderDataFrame[germanyFilter & Filter1982Onwards]
# Out:
#      country continent  year  lifeExp       pop    gdpPercap
# 570  Germany    Europe  1982   73.800  78335266  22031.53274
# 571  Germany    Europe  1987   74.847  77718298  24639.18566
# 572  Germany    Europe  1992   76.070  80597764  26505.30317
# 573  Germany    Europe  1997   77.340  82011073  27788.88416
# 574  Germany    Europe  2002   78.670  82350671  30035.80198
# 575  Germany    Europe  2007   79.406  82400996  32170.37442

# %% [markdown]
# ## Challenge yourself !

# %% [markdown]
# #### Question: How has life expectancy evolved in China ?

# %% [markdown]
# ### Question: Plot the life expectancy evolution of China

# %% [markdown]
# ### Question: Which countries have gdpPerCap larger than 30000 dollars ?

# %% [markdown]
# ### Question: Which countries have gdpPerCap between 500 and 1000 dollars ?

# %% [markdown]
# ### Question: Which countries have gdpPerCap larger than 5000 dollars and are located in Asia ?
