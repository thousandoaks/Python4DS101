# %% [markdown]
# # Lab 2. Getting to know Pandas
# ### Pandas is an open source Python library for data analysis. It gives Python the ability to work with spreadsheet-like data for fast data loading, manipulating, aligning, and merging, among other functions. To give Python these enhanced features, Pandas introduces two new data types to Python: Series and DataFrame. The DataFrame represents your entire spreadsheet or rectangular data, whereas the Series is a single column of the DataFrame.
#
# ### Why should you use a programming language like Python and a tool like Pandas to work with data? It boils down to automation and reproducibility. If a particular set of analyses need to be performed on multiple data sets, a programming language has the ability to automate the analysis on those data sets. Although many spreadsheet programs have their own macro programming languages, many users do not use them. Furthermore, not all spreadsheet programs are available on all operating systems.
#
# ### Objectives
# This chapter will cover:
#
# 1. Loading a simple delimited data file
#
# 2. Counting how many rows and columns were loaded
#
# 3. Determining which type of data was loaded
#
# 4. Looking at different parts of the data by subsetting rows and columns

# %% [markdown]
# ## 1. Let's load pandas library
# ### We kickname it "pd"

# %%
# we import the library pandas and give it the "pd" kickname
import pandas as pd

# %% [markdown]
# ## 2. Loading your first Data Set
# ### Let's bring some data to play with. We use pandas read_csv method to read an external file and load it on our Jupyter

# %%
# we use pandas.read_csv() function to access the file "gapminder.tsv" stored in a remote location 

# the remote location is: https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/

# with the argument sep='\t' we indicate that the columns are separated by tabs rather than commas.

gapminderDataFrame = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
gapminderDataFrame
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# ### We observe that the previous dataframe is a panel data consisted of 6 columns and 1704 observations. Each observation is a row.

# %%
type(gapminderDataFrame)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 3. Let's observe our data

# %%
# we show the first 5 rows
gapminderDataFrame.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# we show the size of our dataset
gapminderDataFrame.shape
# Out:
# (1704, 6)

# %%
# we get some more detailed info on our dataset
gapminderDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# ### 3.1. Let's extract some columns from our data

# %%
# we can extract a column by its name
gapminderDataFrame['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
# we can extract several columns at the same time
gapminderDataFrame[['country','lifeExp']]
# Out:
#           country  lifeExp
# 0     Afghanistan   28.801
# 1     Afghanistan   30.332
# 2     Afghanistan   31.997
# 3     Afghanistan   34.020
# 4     Afghanistan   36.088
# ...           ...      ...
# 1699     Zimbabwe   62.351
# 1700     Zimbabwe   60.377
# 1701     Zimbabwe   46.809
# 1702     Zimbabwe   39.989
# 1703     Zimbabwe   43.487
#
# [1704 rows x 2 columns]

# %% [markdown]
# ## 3.2. Let's extract some rows from our data

# %%
# let's extract the first row. Python starts counting from zero
gapminderDataFrame.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
# let's extract the second row. Python starts counting from zero
gapminderDataFrame.loc[1]
# Out:
# country      Afghanistan
# continent           Asia
# year                1957
# lifeExp           30.332
# pop              9240934
# gdpPercap        820.853
# Name: 1, dtype: object

# %%
# we can even select multiple rows
listofRows=[0,5,10]

gapminderDataFrame.loc[listofRows]
# Out:
#         country continent  year  lifeExp       pop   gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333  779.445314
# 5   Afghanistan      Asia  1977   38.438  14880372  786.113360
# 10  Afghanistan      Asia  2002   42.129  25268405  726.734055

# %%
# we can even select multiple rows by range

gapminderDataFrame.loc[0:8]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395

# %% [markdown]
# ## 4. Grouped and aggregated calculations

# %% [markdown]
# ### There are several initial questions that we can ask ourselves:
# 1. For each year in our data, what was the average life expectancy? What is the average life expectancy, population, and GDP?
# 2. What if we stratify the data by continent and perform the same calculations?
# 3. How many countries are listed in each continent?

# %% [markdown]
# ### 4.1. What was the average life expectancy evolution across time for the whole world ?

# %%
gapminderDataFrame.head(5)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# the following command groups data by the columm "year" then extracts the column lifeExp and computes the mean
gapminderDataFrame.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %% [markdown]
# ### the following figure provides a visual representation of the operation we have just performed

# %% [markdown]
# <img src="./images/groupbyoperation.png" width="50%"/>

# %% [markdown]
# ### 4.2. What was the average life expectancy evolution across time AND continent ?

# %%
# the following command groups data by the columm "year" AND continent then extracts the column lifeExp and computes the mean
gapminderDataFrame.groupby(['year','continent'])['lifeExp'].mean()
# Out:
# year  continent
# 1952  Africa       39.135500
#       Americas     53.279840
#       Asia         46.314394
#       Europe       64.408500
#       Oceania      69.255000
# 1957  Africa       41.266346
#       Americas     55.960280
#       Asia         49.318544
#       Europe       66.703067
#       Oceania      70.295000
# 1962  Africa       43.319442
#       Americas     58.398760
#       Asia         51.563223
#       Europe       68.539233
#       Oceania      71.085000
# 1967  Africa       45.334538
#       Americas     60.410920
#       Asia         54.663640
#       Europe       69.737600
#       Oceania      71.310000
# 1972  Africa       47.450942
#       Americas     62.394920
#       Asia         57.319269
#       Europe       70.775033
#       Oceania      71.910000
# 1977  Africa       49.580423
#       Americas     64.391560
#       Asia         59.610556
#       Europe       71.937767
#       Oceania      72.855000
# 1982  Africa       51.592865
# ...

# %% [markdown]
# ### 4.3. What was the average life expectancy evolution AND GDP per capita across time AND continent ?

# %%
gapminderDataFrame.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %% [markdown]
# ### 4.4. How many countries are there in each continent ?

# %%
gapminderDataFrame.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
#  we group by continent then extract the country column and count unique occurrences
gapminderDataFrame.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %% [markdown]
# ### Groupby Operations are extremely useful, please make sure you understand them

# %% [markdown]
# ## 5. Basic plotting

# %%
gapminderDataFrame.head(4)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138

# %% [markdown]
# ### 5.1 Histograms

# %%
gapminderDataFrame['lifeExp'].hist()

# %%
gapminderDataFrame['gdpPercap'].hist()

# %% [markdown]
# ### 5.2.  Two dimensional scatterplots

# %%
gapminderDataFrame.plot.scatter(x="gdpPercap", y="lifeExp", alpha=0.5)

# %% [markdown]
# ### 5.3.  Time Series

# %% [markdown]
# ### Evolution of life expectancy across time

# %%
gapminderDataFrame.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
# Let's save the previous operation as a new variable

lifeExpectancyEvolution=gapminderDataFrame.groupby('year')['lifeExp'].mean()

# %%
# let's plot the result
lifeExpectancyEvolution.plot()

# %% [markdown]
# # 6. Challenge yourself !

# %% [markdown]
# ## 6.1.   What was the maximum life expectancy evolution across time AND country ?

# %% [markdown]
# ### Hint 1: use the followint command to display all rows in a pandas DataFrame
#
# pandas.set_option('display.max_rows', None)

# %% [markdown]
# ### Hint 2: look on the pandas documentation how to compute the maximum after a groupby operation

# %% [markdown]
# ### https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html
